# %% [markdown]
# Here we test the FDFD code we wrote.

# %%
## Imports

# %%
import scipy.constants as sc
from scipy.sparse import spdiags
import numpy as np
import matplotlib.pyplot as plt

# %%
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
π = np.pi
c0 = sc.c
λ = 1.e-6
ω = 2*π*c0/λ

# %%
## Create the structure

# %%
import fdfd

# %%
from fdfd import geometry
from fdfd.geometry.twodim.circle import Circle

# %%
from scipy.sparse import diags

# %% [markdown]
# # Circle

# %%
cir = Circle(x0=0, y0=0, eps_back=1.0, eps_circ=12.0, radius=0.5e-6)

# %%
Nx = Ny = 200
Nz = 1
cir.make(Nx,Ny)

# %%
# cir.smoothen(Nx,Ny)
plt.imshow(cir.eps)
plt.colorbar()

# %%
## Get fields

# %%
Δx = Δy = np.unique(np.diff(cir.X))[0]

# %%
from fdfd.solve import maxwell

# %%
Ce = maxwell.Ce(Nx, Ny, 1, Δx, Δy, Δz=1)
Ch = maxwell.Ch(Nx, Ny, 1, Δx, Δy, Δz=1)

# %%
from scipy.sparse import csc_matrix

# %%
Ce = csc_matrix(Ce)
Ch = csc_matrix(Ch)

# %%
ϵ = np.hstack((np.ravel(cir.eps), np.ravel(cir.eps), np.ravel(cir.eps)))
Tϵ = spdiags(ϵ, 0, ϵ.shape[0], ϵ.shape[0], format = 'csr')

# %%
μ = np.hstack((np.ravel(cir.mu), np.ravel(cir.mu), np.ravel(cir.mu)))
Tμ = spdiags(μ, 0, μ.shape[0], μ.shape[0], format = 'csr')

# %%
from scipy.sparse import csr_matrix

# %%
jz = np.zeros((Nx,Ny))
jz[Nx//2,Ny//2] = 10
jx = jy = np.zeros((Nx,Ny))
j = np.vstack((jx,jy,jz))
J = csr_matrix(j.flatten()).T

# %%
mx = my = mz = np.zeros((Nx,Ny))
m = np.vstack((mx,my,mz))
M = csr_matrix(m.flatten()).T

# %%
solvedE = maxwell.solveE(Ce, Ch, ω, Tϵ, Tμ, J, M)

# %%
plt.plot(np.abs(solvedE))

# %%
plt.pcolormesh(cir.X, cir.Y, np.reshape(np.abs(solvedE[-(Nx*Ny+1):-1]), (Nx, Ny)))
plt.colorbar()

# %% [markdown]
# # eigensolver

# %%
from fdfd.solve.eigensolver import eigenmode

# %%
eigs = eigenmode.solveE(10, Ce, Ch, ω, Tϵ, Tμ)

# %%
eigs
# Out:
# (array([2.52022043e+23+0.j, 2.52022030e+23+0.j, 2.51885361e+23+0.j,
#         2.51885320e+23+0.j, 2.51945810e+23+0.j, 2.51945838e+23+0.j,
#         2.51945851e+23+0.j, 2.51844346e+23+0.j, 2.51844382e+23+0.j,
#         2.51945851e+23+0.j]),
#  array([[-2.99878502e-09+0.j,  1.30614918e-02+0.j, -2.85800152e-13+0.j,
#          ...,  1.45032054e-02+0.j, -2.47661309e-10+0.j,
#           5.24542631e-14+0.j],
#         [ 2.99555158e-09+0.j, -1.30474143e-02+0.j, -8.43849289e-13+0.j,
#          ..., -1.44364485e-02+0.j,  2.46521463e-10+0.j,
#          -4.14113464e-14+0.j],
#         [-2.98973887e-09+0.j,  1.30221027e-02+0.j,  2.87015089e-12+0.j,
#          ...,  1.43166153e-02+0.j, -2.44475940e-10+0.j,
#           3.03286414e-14+0.j],
#         ...,
#         [-1.84230499e-02+0.j, -4.35609031e-09+0.j, -1.46738884e-04+0.j,
#          ...,  3.37043364e-10+0.j,  2.02883323e-02+0.j,
#           1.00400981e-03+0.j],
#         [ 1.84548669e-02+0.j,  4.36361892e-09+0.j,  4.90119902e-05+0.j,
#          ..., -3.39547002e-10+0.j, -2.04390059e-02+0.j,
#          -8.00922162e-04+0.j],
#         [-1.84707910e-02+0.j, -4.36739023e-09+0.j, -1.84137861e-13+0.j,
#          ...,  3.40801230e-10+0.j,  2.05145184e-02+0.j,
#           5.96308435e-04+0.j]]))

# %%
k = 3
plt.plot(np.abs(eigs[1].T[k]))

# %%
plt.plot(np.abs(eigs[1].T[k][0:(Nx*Ny+1)]))

# %%
plt.pcolormesh(cir.X, cir.Y, np.reshape(np.abs(eigs[1].T[k][0:(Nx*Ny)]), (Nx, Ny)))

# %%
plt.pcolormesh(cir.X, cir.Y, np.reshape(np.abs(eigs[1].T[k][Nx*Ny:2*(Nx*Ny)]), (Nx, Ny)))

# %% [markdown]
# Another approach

# %%
from scipy.sparse.linalg import eigs, inv

# %%
inv(Ch)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-171-d003f3286daa> in <module>
# ----> 1 inv(Ch)
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\matfuncs.py in inv(A)
#      76
#      77     I = _ident_like(A)
# ---> 78     Ainv = spsolve(A, I)
#      79     return Ainv
#      80
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\dsolve\linsolve.py in spsolve(A, b, permc_spec, use_umfpack)
#     210         else:
#     211             # b is sparse
# --> 212             Afactsolve = factorized(A)
#     213
#     214             if not (isspmatrix_csc(b) or is_pydata_spmatrix(b)):
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\dsolve\linsolve.py in factorized(A)
#     486         return solve
#     487     else:
# --> 488         return splu(A).solve
#     489
#     490
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\dsolve\linsolve.py in splu(A, permc_spec, diag_pivot_thresh, relax, panel_size, options)
#     335         _options["SymmetricMode"] = True
#     336
# --> 337     return _superlu.gstrf(N, A.nnz, A.data, A.indices, A.indptr,
#     338                           csc_construct_func=csc_construct_func,
#     339                           ilu=False, options=_options)
#
# RuntimeError: failed to factorize matrix at line 110 in file scipy\sparse\linalg\dsolve\SuperLU\SRC\dsnode_bmod.c

# %%
invTμ = diags(1./Tμ.diagonal())
invTϵ = diags(1./Tϵ.diagonal())
O = -ω**2*invTϵ*invTμ*Ch*Ce

# %%
k_eigs = 5

# %%
newg = eigs(O, k_eigs)

# %%
k = 4
plt.plot(np.abs(newg[1].T[k]))

# %%
plt.pcolormesh(cir.X, cir.Y, np.reshape(np.abs(newg[1].T[k][0:(Nx*Ny)]), (Nx, Ny)))

# %% [markdown]
# # other tests

# %% [markdown]
# Now let us only change by making the circle smaller, on the order of the wavelength...

# %%
cir2 = Circle(x0=0, y0=0, eps_back=1.0, eps_circ=4.0, radius=1.0e-6)
cir2.make(Nx,Ny)
Δx = Δy = np.unique(np.diff(cir2.X))[0]
Ce = maxwell.Ce(Nx, Ny, 1, Δx, Δy, Δz=1)
Ch = maxwell.Ch(Nx, Ny, 1, Δx, Δy, Δz=1)
ϵ = np.hstack((np.ravel(cir2.eps), np.ravel(cir2.eps), np.ravel(cir2.eps)))
Tϵ = spdiags(ϵ, 0, ϵ.shape[0], ϵ.shape[0], format = 'csr')
μ = np.hstack((np.ravel(cir2.mu), np.ravel(cir2.mu), np.ravel(cir2.mu)))
Tμ = spdiags(μ, 0, μ.shape[0], μ.shape[0], format = 'csr')
solvedE = maxwell.solveE(Ce, Ch, ω, Tϵ, Tμ, j, m)

# %%
fig, axs = plt.subplots(1,2, figsize=(10,4))
axs[0].pcolormesh(cir2.X, cir2.Y, cir2.eps)
axs[1].pcolormesh(cir2.X, cir2.Y, np.reshape(np.abs(solvedE[-10001:-1])**2, (Nx, Ny)))

# %%
cir3 = Circle(x0=0, y0=0, eps_back=1.0, eps_circ=4.0, radius=5.0e-6)
cir3.make(Nx,Ny)
Δx = Δy = np.unique(np.diff(cir3.X))[0]
Ce = maxwell.Ce(Nx, Ny, 1, Δx, Δy, Δz=1)
Ch = maxwell.Ch(Nx, Ny, 1, Δx, Δy, Δz=1)
ϵ = np.hstack((np.ravel(cir3.eps), np.ravel(cir3.eps), np.ravel(cir3.eps)))
Tϵ = spdiags(ϵ, 0, ϵ.shape[0], ϵ.shape[0], format = 'csr')
μ = np.hstack((np.ravel(cir3.mu), np.ravel(cir3.mu), np.ravel(cir3.mu)))
Tμ = spdiags(μ, 0, μ.shape[0], μ.shape[0], format = 'csr')
solvedE = maxwell.solveE(Ce, Ch, ω, Tϵ, Tμ, j, m)

fig, axs = plt.subplots(1,2, figsize=(10,4))
axs[0].pcolormesh(cir3.X, cir3.Y, cir2.eps)
axs[1].pcolormesh(cir3.X, cir3.Y, np.reshape(np.abs(solvedE[-10001:-1])**2, (Nx, Ny)))
